# %%
import pandas as pd

# %%
PlayerPersonalData = pd.read_csv('PlayerPersonalData.csv', low_memory=False)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Гистограмма потенциала указывает на доминирующий потенциал и особенности распределения

# %%
PlayerPersonalData.Potential.plot.hist()
plt.legend()
plt.title('Player potential histogram', fontdict={'fontsize': 20})
plt.xlabel('Рotential')
# Out:
# Text(0.5, 0, 'Рotential')

# %% [markdown]
# Из гистограммы видно, что наибольшее количество игроков с потенцилом раным 70-73
